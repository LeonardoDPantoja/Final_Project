# %%
#Instalar libreria Altair.
# !pip install altair vega_datasets
# Out:
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (4.2.2)
# Requirement already satisfied: vega_datasets in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair) (4.19.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from altair) (1.23.5)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from altair) (1.5.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair) (0.12.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)

# %%
#Importando librerias necesarias para proyecto.
import altair as alt
from vega_datasets import data
import pandas as pd
import numpy as np
from IPython.display import Image
alt.renderers.enable('mimetype')
alt.renderers.enable('colab')
# Out:
# RendererRegistry.enable('colab')

# %%
#Leer base de datos a utilizar.
data_venta=pd.read_csv('Datos_Ventas_TIendas.csv', encoding='latin-1')

#Vizualización de la base de datos y sus primeros 5 reglones de datos.
data_venta.head(5)
# Out:
#                       Estado           Ciudad                    coordenadas  \
# 0  CHIHUAHUA                  CD JUAREZ           31.7390805,-106.6298246,12
# 1  SINALOA                    CULIACAN          24.8084179,-107.4003212,17.5
# 2  SINALOA                    CULIACAN         24.8062124,-107.3982179,18.25
# 3  SINALOA                    CULIACAN         24.8001665,-107.3989983,16.25
# 4  SINALOA                    CULIACAN         24.7942375,-107.4158336,17.25
#
#    Tienda       Tipo    dic-22    nov-22    oct-22    sep-22    ago-22  \
# 0      15  Receptora  50612000  33852000  27367000  24830000  26913000
# 1      16  Receptora  54774000  31854000  25127000  23145000  25571000
# 2      17  Receptora  30009000  13998000  10266000   9812000  11010000
# 3      18  Receptora   9870000   5972000   4686000   4414000   4645000
# 4      19  Receptora  41301000  25055000  18477000  17959000  19315000
#
#      jul-22    jun-22    may-22    abr-22    mar-22    feb-22    ene-22  \
# 0  29797000  27891000  28283000  26712000  24351000  21560000  18578000
# 1  24785000  23280000  27140000  24207000  22068000  18115000  16860000
# 2  10524000  10918000  13824000  15537000  14139000  13066000  10828000
# 3   4284000   4335000   5155000   4265000   4805000   4070000   3540000
# 4  19977000  18835000  22606000  20126000  18598000  15395000  14475000
#
#         suma      ganancia
# 0  340746000  2.213650e+08
# 1  316926000  2.058929e+08
# 2  163931000  1.064788e+08
# 3   60041000  3.892365e+07
# 4  252119000  1.637482e+08

# %%
# Pedir tipo de dato de cada variable de la base de datos.
data_venta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1712 entries, 0 to 1711
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Estado       1712 non-null   object
#  1   Ciudad       1712 non-null   object
#  2   coordenadas  1712 non-null   object
#  3   Tienda       1712 non-null   int64
#  4   Tipo         1712 non-null   object
#  5   dic-22       1712 non-null   int64
#  6   nov-22       1712 non-null   int64
#  7   oct-22       1712 non-null   int64
#  8   sep-22       1712 non-null   int64
#  9   ago-22       1712 non-null   int64
#  10  jul-22       1712 non-null   int64
#  11  jun-22       1712 non-null   int64
#  12  may-22       1712 non-null   int64
#  13  abr-22       1712 non-null   int64
#  14  mar-22       1712 non-null   int64
#  15  feb-22       1712 non-null   int64
#  16  ene-22       1712 non-null   int64
#  17  suma         1712 non-null   int64
#  18  ganancia     1712 non-null   float64
# dtypes: float64(1), int64(14), object(4)
# memory usage: 254.2+ KB

# %%
#Creación de una grafica con marcador de promedio anual de variable con Altair.
Ventas=alt.Chart(data_venta).mark_bar().encode(
    x='Tienda',
    y='suma'
)

linea = alt.Chart(data_venta).mark_rule(color='red').encode(
    y='mean(suma)'
)

(Ventas + linea).properties(width=600)
ventas="ventas.png"
Image(filename=ventas)

# %%
#Creación de un histograma del mes de diciembre con Altair.
tienda=alt.Chart(data_venta).mark_bar().encode(
    x='Tienda',
    y='dic-22'
)

tienda="tienda.png"
Image(filename=tienda)

# %%
#Creación de diagrama de disperción con Altair.
venta_dis=alt.Chart(data_venta).mark_circle().encode(
    x='Tienda',
    y='dic-22'
)

venta_dis="venta_dist.png"
Image(filename=venta_dis)

# %%
#Leer base de datos #2 a utilizar.
data_gasto=pd.read_csv('Datos_Gastos_Tiendas.csv', encoding='latin-1')
data_gasto
# Out:
#                          Estado           Ciudad    latitud    longitud  \
# 0     CHIHUAHUA                  CD JUAREZ        31.739081 -106.629825
# 1     SINALOA                    CULIACAN         24.808418 -107.400321
# 2     SINALOA                    CULIACAN         24.806212 -107.398218
# 3     SINALOA                    CULIACAN         24.800166 -107.398998
# 4     SINALOA                    CULIACAN         24.794238 -107.415834
# ...                         ...              ...        ...         ...
# 1707  MICHOACAN                  PATZCUARO        17.218336 -100.432006
# 1708  SINALOA                    LOS MOCHIS       20.095924  -98.716151
# 1709  CAMPECHE                   CAMPECHE         19.480818  -99.124703
# 1710  PUEBLA                     PUEBLA           29.036859 -110.946121
# 1711  VERACRUZ                   COATZACOALCOS    22.898167 -110.006667
#
#       Tienda         Tipo    dic-22    nov-22    oct-22    sep-22   ago-22  \
# 0         15    Receptora   6289.91   6286.86   6286.86   6286.86  6291.43
# 1         16    Receptora   9449.10   9467.88   9449.10   9449.10  9449.10
# 2         17    Receptora   6949.82   6949.82   6949.82   6169.82  6169.82
# 3         18    Receptora  11668.38  11666.86  11668.38  11152.96  8425.26
# 4         19    Receptora  12410.86  12410.86  11819.56   7960.86  7960.86
# ...      ...          ...       ...       ...       ...       ...      ...
# 1707    1722  Redundancia  18077.73  18077.73      1.00      1.00     1.00
# 1708    1723    Receptora   9720.83  19619.97      1.00      1.00     1.00
# 1709    1724  Redundancia  16103.91  19292.06      1.00      1.00     1.00
# 1710    1725    Receptora   9138.29  19714.13      1.00      1.00     1.00
# 1711    1726  Redundancia  19070.98  20102.06      1.00      1.00     1.00
#
#         jul-22    jun-22    may-22    abr-22    mar-22    feb-22    ene-22  \
# 0      5814.17   6286.86  15430.81  15525.41  14284.93  14283.41  16848.00
# 1      8976.41   9449.10  10268.10   9392.35   7490.10   7490.10   8688.52
# 2      6477.13   6949.82   7049.15   5999.09   5286.97   5284.75   6132.07
# 3     11194.17  11668.38   5807.51   5026.10   4549.91   4551.43   5621.34
# 4     11938.17  11819.56  10254.06  10515.46  10150.86  10150.86  11775.00
# ...        ...       ...       ...       ...       ...       ...       ...
# 1707  20070.67      1.00      1.00      1.00      1.00      1.00      1.00
# 1708  19619.97      1.00      1.00      1.00      1.00      1.00      1.00
# 1709  19292.06      1.00      1.00      1.00      1.00      1.00      1.00
# 1710  19714.13      1.00      1.00      1.00      1.00      1.00      1.00
# 1711  20102.06      1.00      1.00      1.00      1.00      1.00      1.00
#
#            suma
# 0     119915.51
# 1     109018.96
# 2      76368.08
# 3     103000.68
# 4     129166.97
# ...         ...
# 1707   56235.13
# 1708   48969.77
# 1709   54697.03
# 1710   48575.55
# 1711   59284.10
#
# [1712 rows x 19 columns]

# %%
#Creación de una grafica con marcador de promedio anual de variable con Altair.
Gasto=alt.Chart(data_gasto).mark_bar().encode(
    x='Tienda',
    y='suma'
)

linea = alt.Chart(data_gasto).mark_rule(color='red').encode(
    y='mean(suma)'
)

(Gasto + linea).properties(width=600)
gasto="gasto.png"
Image(filename=gasto)

# %%
#Creación de un histograma con marcador de promedio anual con Altair.
ganancia=alt.Chart(data_venta).mark_bar().encode(
    x='Tienda',
    y='ganancia'
)

linea = alt.Chart(data_venta).mark_rule(color='red').encode(
    y='mean(ganancia)'
)

(ganancia + linea).properties(width=600)
Ganancia="ganancia.png"
Image(filename=Ganancia)

# %%
#Creación de un histograma con Altair.
ganancia_=alt.Chart(data_venta).mark_circle().encode(
    x='Tienda',
    y='ganancia'
)

ganancia_
Ganancia_="ganancia_.png"
Image(filename=Ganancia_)

# %%
#Creación de dataframe con los datso necesarios de diferentes base de datos.
conjunto=pd.DataFrame({
    'Tienda':(data_venta['Tienda']),
    'Tipo':(data_venta['Tipo']),
    'Ventas':(data_venta['suma']),
    'Ganancia':(data_venta['ganancia']),
    'Gasto_Telecom':(data_gasto['suma'])
})

conjunto
# Out:
#       Tienda         Tipo     Ventas      Ganancia  Gasto_Telecom
# 0         15    Receptora  340746000  2.213650e+08      119915.51
# 1         16    Receptora  316926000  2.058929e+08      109018.96
# 2         17    Receptora  163931000  1.064788e+08       76368.08
# 3         18    Receptora   60041000  3.892365e+07      103000.68
# 4         19    Receptora  252119000  1.637482e+08      129166.97
# ...      ...          ...        ...           ...            ...
# 1707    1722  Redundancia     275011  1.225239e+05       56235.13
# 1708    1723    Receptora     583011  3.299892e+05       48969.77
# 1709    1724  Redundancia    1865011  1.157562e+06       54697.03
# 1710    1725    Receptora    2907011  1.840983e+06       48575.55
# 1711    1726  Redundancia    4075011  2.589475e+06       59284.10
#
# [1712 rows x 5 columns]

# %%
#visualización y creación de grafica de los diferentes tipos de tiendas.
tipos = alt.Chart(conjunto).mark_bar().encode(
    x=alt.X('count(Tienda):Q',stack='zero'),
    y=alt.Y('Tipo:N'),
    color=alt.Color('Tipo')
)

tipos
Tipos="tipos.png"
Image(filename=Tipos)

# %%
#Conteo de todas las tiendas.
tiendas=conjunto['Tienda'].count()
tiendas
# Out:
# 1712

# %%
#Conteo de los tipos de tiendas.
categoria=conjunto['Tipo'].nunique()
categoria
# Out:
# 3

# %%
#creación de grafica apilada de la cantidad de tiendas por tipo de ellas.
grafica=pd.DataFrame({
    'Tipo':['Matriz','Receptora','Redudancia'],
    'Tiendas':[1712,1712,1712],
    'Cantidad_Tienda':[926,611,187]
})

tipo_=alt.Chart(grafica).mark_bar(dx=-15, dy=3, color='white').encode(
    x=alt.X('sum(Cantidad_Tienda):Q'),
    y=alt.Y('Tiendas:N'),
    color='Tipo:N'
)

tipo_
Tipo="tipo_.png"
Image(filename=Tipo)

# %%
#Elaboración de grafica de área con libraria altair.
venta_tipo=alt.Chart(conjunto).mark_area(opacity=0.6).encode(
    x="Tienda:T",
    y=alt.Y("Ganancia:Q",stack=None),
    color="Tipo:N"
)

venta_tipo="venta_tipo.png"
Image(filename=venta_tipo)

# %%
#Leer base de datos #3 a utilizar.
data_local=pd.read_csv('Datos_Localidad.csv', encoding='latin-1')
data_local
# Out:
#      Localidad  tipo_ventaxlocal      ventas  tipo_gastoxlocal  gasto_telecom  \
# 0            1                 2  1236702000                 1        1954903
# 1            2                 1   211085000                 3         300898
# 2            3                 1   128518000                 3         302339
# 3            4                 1   119284000                 3         290199
# 4            5                 1    60990000                 3         487245
# ..         ...               ...         ...               ...            ...
# 607        614                 1   169823000                 2         569294
# 608        615                 1    38459000                 3         298691
# 609        616                 1    64194000                 3         277100
# 610        617                 1   131417000                 3         308426
# 611        618                 1    24738000                 3         260482
#
#      tipo_gananxlocal  ganancias  clima_promxlocal  pobla_total  cant_mujeres  \
# 0                   2  801744332                20        29002         14796
# 1                   1  136900422                20        13922          7166
# 2                   1   83246195                19        56597         29703
# 3                   1   77243771                20        19976         10345
# 4                   1   39349955                18       658609        345979
# ..                ...        ...               ...          ...           ...
# 607                 1  109815656                17        11487          6208
# 608                 1   24699659                19         9668          5030
# 609                 1   41449000                18        70760         36613
# 610                 1   85112624                19        14732          7791
# 611                 1   15819218                22        14226          7514
#
#      cant_hombres  cant_menor_edad  cant_niñas  cant_niños
# 0           14206            11206        5550        5656
# 1            6756             5211        2590        2621
# 2           26894            19146        9514        9632
# 3            9631             6431        3120        3311
# 4          312630           183298       90145       93153
# ..            ...              ...         ...         ...
# 607          5279             3749        1855        1894
# 608          4638             2384        1141        1243
# 609         34147            21788       10705       11083
# 610          6941             4911        2433        2478
# 611          6712             4380        2214        2166
#
# [612 rows x 14 columns]

# %%
#Creación de un histograma con Altair.
clima=alt.Chart(data_local).mark_bar().encode(
    x='Localidad',
    y='clima_promxlocal'
)

linea = alt.Chart(data_local).mark_rule(color='red').encode(
    y='mean(clima_promxlocal)'
)

(clima + linea).properties(width=600)
Clima="clima.png"
Image(filename=Clima)

# %%
#Creación de un histograma con Altair.
pobla_t=alt.Chart(data_local).mark_bar().encode(
    x='Localidad',
    y='pobla_total'
)

linea = alt.Chart(data_local).mark_rule(color='red').encode(
    y='mean(pobla_total)'
)

(pobla_t + linea).properties(width=600)

Pobla_T="pobla_t.png"
Image(filename=Pobla_T)

# %%
#Suma de la variable.
mujeres=data_local['cant_mujeres'].sum()
mujeres
# Out:
# 37059220

# %%
#Suma de la variable.
niñas=data_local['cant_niñas'].sum()
niñas
# Out:
# 9941647

# %%
#obtención de cantidad de la variable.
muj_mayo_edad=mujeres-niñas
muj_mayo_edad
# Out:
# 27117573

# %%
#Suma de la variable.
hombres=data_local['cant_hombres'].sum()
hombres
# Out:
# 34926237

# %%
#Suma de la variable.
niños=data_local['cant_niños'].sum()
niños
# Out:
# 10232485

# %%
#obtención de cantidad de la variable.
hom_mayo_edad=hombres-niños
hom_mayo_edad
# Out:
# 24693752

# %%
#obtención de cantidad de la variable.
menor_edad=niñas+niños
menor_edad
# Out:
# 20174132

# %%
#obtención de cantidad de la variable.
mayor_edad=muj_mayo_edad+hom_mayo_edad
mayor_edad
# Out:
# 51811325

# %%
#obtención de cantidad de la variable.
total=mujeres+hombres
total
# Out:
# 71985457

# %%
#creación de grafica apilada de la cantidad y tipo de población.
grafica=pd.DataFrame({
    'Genero':['mujeres','mujeres','hombres','hombres'],
    'Edad':['menor_edad','mayor_edad','menor_edad','mayor_edad'],
    'Poblacion_Total':[9941647,27117573,10232485,24693752]
})

genero=alt.Chart(grafica).mark_bar().encode(
    x='Poblacion_Total',
    y='Edad',
    color='Genero'
)

genero
Genero="genero.png"
Image(filename=Genero)

# %%
#creación de grafica de pastel con la cantidad y tipo de población.
date = pd.DataFrame(
    {"Genero": ['Mujeres','Hombres'],
     "Poblacion": [37059220,34926237]}
)


dona=alt.Chart(date).mark_arc(innerRadius=50).encode(
    theta="Poblacion",
    color="Genero:N",
)

dona
Dona="dona.png"
Image(filename=Dona)

# %%
#Leer base de datos #4 a utilizar.
data_estado=pd.read_csv('Datos_Estados.csv', encoding='latin-1')
data_estado
# Out:
#     estado       ventas  gasto_telecom    ganancias  pobla_total  \
# 0        1   1756579000   3.335584e+06   1138484675      4050980
# 1        2   9619419000   1.078116e+07   6241043401     12785132
# 2        3   3527741000   6.169197e+06   2286777646      2791880
# 3        4   1765429000   2.490158e+06   1144951511      2095936
# 4        5   6745356000   9.907439e+06   4374563783      6229068
# 5        6   7266322000   1.088867e+07   4711905055     12302056
# 6        7   7609835000   1.129277e+07   4935064218     10719824
# 7        8   1737256000   3.027845e+06   1126160923      2330628
# 8        9   8760597000   2.425076e+07   5668791221     35374824
# 9       10   3524625000   8.013524e+06   2282930068      4467104
# 10      11  22250586000   4.420003e+07  14418402066     36619561
# 11      12  10365206000   1.568965e+07   6721936692     14926804
# 12      13   5615412000   9.371541e+06   3641255673      5562664
# 13      14   4748778000   9.022407e+06   3077793385      3401460
# 14      15  11818162000   2.790357e+07   7653913177     19416072
# 15      16   7659838000   1.373216e+07   4965647833      8725488
# 16      17   3734414000   7.040279e+06   2420418133      3858252
# 17      18   3002128000   5.902357e+06   1945623272      2247644
# 18      19   8491937000   1.307902e+07   5506508969     15711616
# 19      20   9934304000   1.999443e+07   5551443673      4662896
# 20      21   3457060000   5.181417e+06   6437412853     11358884
# 21      22   3972549000   4.252442e+06   2241703938      4705508
# 22      23   4860779000   6.982399e+06   2577729422      5912160
# 23      24  10247298000   1.453295e+07   3152319170      6187968
# 24      25   7523989000   1.261344e+07   6645848954      7924388
# 25      26   3576611000   4.961440e+06   4877822315      9255468
# 26      27   6538697000   8.437255e+06   2319609637      2331628
# 27      28   2433468000   5.545891e+06   4241629538      9331191
# 28      29  15907855000   3.554274e+07   1576884193      1679928
# 29      30   3436081000   5.908149e+06  10305561181     12146244
# 30      31   1581487000   3.865141e+06   2227577649      5610904
# 31      32   2281735000   4.942266e+06   1024007803      1769380
#
#     cant_mujeres  cant_hombres  cant_menor:edad  cant_niñas  cant_niños  ...  \
# 0        2083220       1967760          1252892      617556      635336  ...
# 1        6369760       6415372          3505072     1720704     1784368  ...
# 2        1380484       1411396           823056      404900      418156  ...
# 3        1082880       1013056           585120      287724      297396  ...
# 4        3267672       2961396          1937054      957745      979309  ...
# 5        6231504       6070552          3643724     1791160     1852564  ...
# 6        5414316       5305508          3326436     1636016     1690420  ...
# 7        1190420       1140208           809132      397520      411612  ...
# 8       18472808      16902016          7706064     3794516     3911548  ...
# 9        2292640       2174464          1420032      697192      722840  ...
# 10      18910814      17708747          9751121     4822208     4928913  ...
# 11       7667200       7259604          5468324     2690588     2777736  ...
# 12       2920820       2641844          1673420      825228      848192  ...
# 13       1787508       1613952           952524      470756      481768  ...
# 14       9966377       9449695          5393146     2659455     2733691  ...
# 15       4533264       4192224          2634076     1302296     1331780  ...
# 16       2020804       1837448          1035472      509432      526040  ...
# 17       1161908       1085736           668660      328212      340448  ...
# 18       7895616       7816000          4206620     2067548     2139072  ...
# 19       2465700       2197196          1390136      687532      702604  ...
# 20       5953736       5405148          3266348     1611900     1654448  ...
# 21       2420036       2285472          1220992      600832      620160  ...
# 22       2942364       2969796          1656916      816528      840388  ...
# 23       3205632       2982336          1761972      870492      891480  ...
# 24       4077976       3846412          2293764     1128484     1165280  ...
# 25       4672588       4582880          2731532     1343864     1387668  ...
# 26       1218564       1113064           632700      312104      320596  ...
# 27       4774545       4556646          2717479     1338052     1379427  ...
# 28        874248        805680           523372      259472      263900  ...
# 29       6459036       5687208          3198360     1579896     1618464  ...
# 30       2895408       2715496          1487052      733156      753896  ...
# 31        915668        853712           558736      276084      282652  ...
#
#     piso_tier  prom_habit_viv  prom_ingr_trim  gast_alim_esta_trim  \
# 0        2899             3.7           58303                12303
# 1       22576             3.3           67821                11954
# 2       11234             3.3           64266                12812
# 3        7150             3.6           47276                10846
# 4      149481             4.1           29168                 8069
# 5       21790             3.2           60263                 9728
# 6        7270             3.5           55671                10320
# 7        5756             3.2           56297                13038
# 8       16199             3.3           67357                14887
# 9       17650             3.7           50361                10561
# 10      92762             3.7           49620                12633
# 11      37095             3.9           48388                11342
# 12     132012             3.7           32516                 9480
# 13      24402             3.6           40090                 9718
# 14      35773             3.6           55746                13375
# 15      66867             3.7           46410                12384
# 16      21532             3.5           42041                10875
# 17      11279             3.4           51965                12713
# 18      13939             3.5           72931                11845
# 19     149170             3.7           36263                 9326
# 20      87193             3.8           39616                10223
# 21      12875             3.5           60435                13012
# 22      12803             3.2           46380                11466
# 23      37830             3.6           47819                10628
# 24      19497             3.5           55834                11484
# 25      21326             3.3           61358                10923
# 26      23000             3.6           41665                 9669
# 27      16010             3.3           49688                 9969
# 28       6252             3.9           37919                 9607
# 29     136800             3.4           35126                 9064
# 30       9250             3.5           46766                12197
# 31       5878             3.7           44405                10553
#
#     gast_vest_esta_trim  gast_viv_serv_trim  gast_mueb_limp_trim  \
# 0                  1327                3159                 2261
# 1                   991                5704                 2426
# 2                   942                4330                 2526
# 3                   659                2276                 2019
# 4                   668                1541                 1541
# 5                   718                3607                 1897
# 6                  1071                3530                 2439
# 7                   988                3357                 2304
# 8                  1008                5837                 2087
# 9                  1062                2470                 2243
# 10                  834                3279                 1670
# 11                  947                2995                 1930
# 12                  677                1562                 1531
# 13                  787                2172                 1502
# 14                 1064                4276                 2061
# 15                 1406                2418                 2294
# 16                  775                2506                 1726
# 17                 1104                2371                 2135
# 18                  853                4758                 2678
# 19                  675                1375                 1566
# 20                  991                2524                 1636
# 21                 1206                4277                 2253
# 22                  548                4003                 1972
# 23                  949                2467                 2029
# 24                 1149                3559                 2254
# 25                  803                4671                 2069
# 26                  427                1737                 1686
# 27                  645                3291                 1966
# 28                 1122                2149                 1541
# 29                  770                2080                 1806
# 30                  520                2093                 2264
# 31                 1094                2291                 2134
#
#     gast_salud_trim  gast_tras_trim  gast_educ_trim
# 0              1647            7661            3299
# 1              1172            8315            2412
# 2              1149            7308            2237
# 3              1288            5400            2274
# 4               988            3015            1260
# 5               766            6059            2088
# 6              1130            6784            2826
# 7              1403            7176            2499
# 8              1482            5724            2765
# 9              1046            5725            2211
# 10              937            5960            2314
# 11              967            4716            2242
# 12             1225            3665            1264
# 13             1617            4390            1850
# 14             1404            6600            2374
# 15             1875            5841            2600
# 16             1182            5005            1805
# 17             1427            6340            1842
# 18             1439            7147            4004
# 19             1346            3434            1457
# 20             1499            4362            2213
# 21             1557            6652            3488
# 22              836            5486            1778
# 23             1366            5050            2883
# 24             2125            6835            2456
# 25             1167            6620            2578
# 26              886            4322            1526
# 27             1120            6090            2208
# 28             1071            4096            1920
# 29             1227            4123            1722
# 30             1517            5159            2195
# 31             1462            5306            1749
#
# [32 rows x 34 columns]

# %%
#creación de grafica apilada de la cantidad y los partidos politicos.
partido = pd.DataFrame(
    {"Partido_politico": ['Morena','PRI','PAN','Movimiento_Ciudadano','Partido_Verde'],
     'N_Estados':[32,32,32,32,32],
     "Cantidad_Estados": [21,3,5,2,1]}
)

tipo_=alt.Chart(partido).mark_bar(dx=-15, dy=3, color='white').encode(
    x=alt.X('sum(Cantidad_Estados):Q'),
    y=alt.Y('N_Estados:N'),
    color='Partido_politico:N'
)

tipo_
Tipo_="tipo_.png"
Image(filename=Tipo_)

# %%
#creación de grafica de pastel con la cantidad y prtido politicos.
partido = pd.DataFrame(
    {"Partido_politico": ['Morena','PRI','PAN','Movimiento_Ciudadano','Partido_Verde'],
     "N_Estados": [21,3,5,2,1]}
)


dona_p=alt.Chart(partido).mark_arc(innerRadius=50).encode(
    theta="N_Estados",
    color="Partido_politico:N",
)

dona_p
Dona_p="dona_p.png"
Image(filename=Dona_p)

# %%
#creación de grafica apilada de la cantidad y tipo de situación.
grafica=pd.DataFrame({
    'Situacion':['Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Nacimiento','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion','Defuncion'],
    'Estado_Rep':['Aguascalientes','Baja_California_Norte','Baja_Callifornia_Sur','Campeche','Chiapas','Chihuahua','Coahuila','Colima','Distrito_Federal','Durango','Estado_Mexico','Guanajuato','Guerrero','Hidalgo','Jalisco','Michoacan','Morelos','Nayarit','Nuevo_Leon','Oaxaca','Puebla','Queretaro','Quintana_Roo','San_Potosi','Sinaloa','Sonora','Tabasco','Tamaulipas','Tlaxcala','Veracruz','Yucatan','Zacatecas','Aguascalientes','Baja_California_Norte','Baja_Callifornia_Sur','Campeche','Chiapas','Chihuahua','Coahuila','Colima','Distrito_Federal','Durango','Estado_Mexico','Guanajuato','Guerrero','Hidalgo','Jalisco','Michoacan','Morelos','Nayarit','Nuevo_Leon','Oaxaca','Puebla','Queretaro','Quintana_Roo','San_Potosi','Sinaloa','Sonora','Tabasco','Tamaulipas','Tlaxcala','Veracruz','Yucatan','Zacatecas'],
    'Cantidad':[20370,47945,10081,10729,45815,8948,98098,48095,65703,27988,85259,59150,37498,119604,184447,73115,24662,16524,74471,52031,104228,33211,24063,41812,38971,30904,28943,44297,20610,92325,29321,26309,9548,32662,4867,7549,28190,6057,38908,39246,107292,13945,51677,25859,22655,64461,152668,36614,18442,8708,42418,33072,56745,15114,11003,24427,23962,27814,21871,28025,12033,74758,18221,14519]
})



nac_def=alt.Chart(grafica).mark_bar().encode(
    x='sum(Cantidad):Q',
    y='Estado_Rep:N',
    color='Situacion:N'
)

nac_def
Nac_d="nac_def.png"
Image(filename=Nac_d)

# %%
# Pedir tipo de dato de cada variable de la base de datos.
data_estado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   estado               32 non-null     int64
#  1   ventas               32 non-null     int64
#  2   gasto_telecom        32 non-null     float64
#  3   ganancias            32 non-null     int64
#  4   pobla_total          32 non-null     int64
#  5   cant_mujeres         32 non-null     int64
#  6   cant_hombres         32 non-null     int64
#  7   cant_menor:edad      32 non-null     int64
#  8   cant_niñas           32 non-null     int64
#  9   cant_niños           32 non-null     int64
#  10  part_polit_gob       32 non-null     int64
#  11  def_x_est            32 non-null     int64
#  12  def_x_est_muj        32 non-null     int64
#  13  def_x_est_hom        32 non-null     int64
#  14  nacim_x_est          32 non-null     int64
#  15  nacim_x_est_a        32 non-null     int64
#  16  nacim_x_est_o        32 non-null     int64
#  17  porc_nac_x_est       32 non-null     float64
#  18  cant_nac_x_est       32 non-null     int64
#  19  viv_part_habit       32 non-null     int64
#  20  pobl_pobre_est       32 non-null     float64
#  21  pobl_probre_mode     32 non-null     float64
#  22  pobl_probre_extr     32 non-null     float64
#  23  piso_mat_durab       32 non-null     int64
#  24  piso_tier            32 non-null     int64
#  25  prom_habit_viv       32 non-null     float64
#  26  prom_ingr_trim       32 non-null     int64
#  27  gast_alim_esta_trim  32 non-null     int64
#  28  gast_vest_esta_trim  32 non-null     int64
#  29  gast_viv_serv_trim   32 non-null     int64
#  30  gast_mueb_limp_trim  32 non-null     int64
#  31  gast_salud_trim      32 non-null     int64
#  32  gast_tras_trim       32 non-null     int64
#  33  gast_educ_trim       32 non-null     int64
# dtypes: float64(6), int64(28)
# memory usage: 8.6 KB

# %%
#creación de  gráfica de área de la cantidad de viviendas habitadas por estados.
viviendas=alt.Chart(data_estado).mark_area(
    line={'color':'darkgreen'},
    color=alt.Gradient(
        gradient='linear',
        stops=[alt.GradientStop(color='white', offset=0),
               alt.GradientStop(color='darkgreen', offset=1)],
        x1=1,
        x2=1,
        y1=1,
        y2=0
    )
).encode(
    alt.X('estado:Q'),
    alt.Y('viv_part_habit:Q')
)

viviendas
Viviendas="vivienda.png"
Image(filename=Viviendas)

# %%
#creación de  gráfica de linea de la cantidad de viviendas habitadas por estados.
alt.Chart(data_estado).mark_area(
    color="lightblue",
    interpolate='step-after',
    line=True
).encode(
    x='estado:T',
    y='viv_part_habit:Q'
)

Can="cantidad.png"
Image(filename=Can)

# %% [markdown]
# ##Referencias:
#
# Usos y tipos de graficos con la librería Altair.
# Link:
# https://altair-viz.github.io/index.html
#
# Victor Cupisnera (2023) Visualización con Altair.
# En el siguiente Link: https://github.com/vcuspinera/UDG_MCD_Project_Dev_I/blob/main/actividades/12_Viz_Altair.ipynb
#
# Sergio Sánchez (2018) Visualización de Datos con Altair.
# Link: https://medium.com/datos-y-ciencia/visualizaci%C3%B3n-de-datos-con-altair-297b0639448d
